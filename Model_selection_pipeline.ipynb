# %% [markdown]
# # **Model Selection Pipeline **

# %%
#In this i have already run all model each and having before and after hyperparameter tuning metrics

# %% [markdown]
# **Logistics Regression **

# %% [markdown]
# Model Performance Comparison base model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After Hyperparameter tunning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Random Forest **

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # XGBOOST Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ANN model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ANN after hyperparameter**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Choosing the **Random Forest Classifier** as your model depends on several factors. Let’s break it down based on the evaluation metrics and typical considerations:

# %% [markdown]
# # Why Choose Random Forest?
#
# **Performance Metrics:**
#
# **Accuracy:**
#  It achieved 0.84 after hyperparameter tun, which is competitive.
# Precision, Recall,
#  F1: The tuned model improved recall (0.89) and F1-score (0.85), which are critical for imbalanced datasets.
#
# These metrics suggest it handles both false positives and false negatives effectively.
#
# **Robustness:**
#
# Random Forest is less prone to overfitting compared to single-tree models.
# It performs well with noisy data and is resilient to outliers.
#
#
#
# **Scalability:**
#
# Random Forest can handle both small and large datasets efficiently.
#
# **Versatility:**
#
# It works well for both classification and regression tasks.
# Handles non-linear relationships better than models like Logistic Regression.

# %% [markdown]
# Easy to *Interpret*

# %% [markdown]
# # Decision
#
# **Given the evaluation results:**
#
# Random Forest achieved high performance after tuning, with balanced precision and recall.
# It’s easier to deploy and interpret than ANN or XGBoost.
# It has proven robustness across a variety of datasets and use cases.
# Thus, Random Forest Classifier appears to be the best choice for this problem, unless:
#
# A significantly higher performance metric is achieved by another model.
# Specific requirements (e.g., speed, interpretability) favor a different model.
# Let me know if you'd like further clarification or to explore additional insights!
